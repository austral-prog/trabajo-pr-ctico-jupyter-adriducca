# %% [markdown]
# # Adriano Ducca aducca@mail.austral.edu.ar
# # [EXERCISE 1]
# ![image.png](attachment:351bacb2-c203-4104-a5f3-0f2b3133b58d.png)![image.png](attachment:33c7177f-d527-43d9-bad4-9412421681cf.png)
# Este es uno de mis autos faviritos, es el porshe gt3 rs el cual tiene una velocidad maxima de 296km/h

# %% [markdown]
# ---

# %%
a=3
b=7

# %% [markdown]
# # SUMA

# %%
(a+b)
# Out:
# 10

# %% [markdown]
# # RESTA

# %%
(a-b)
# Out:
# -4

# %% [markdown]
# # MULTIPLICACION

# %%
(a*b)
# Out:
# 21

# %% [markdown]
# # DIVISION

# %%
(a/b)
# Out:
# 0.42857142857142855
